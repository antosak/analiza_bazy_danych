# %%
# !pip install sqlalchemy psycopg2 pandas

# %%
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2 as pg
import pandas as pd
# nazwa_silnika://użytkownik:hasło@adres_serwera:port/nazwa_bazy
db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)
connection_sqlalchemy = db.connect()

# %% [markdown]
# Zadanie 1

# %%
zad1 = pd.read_sql('select name from category', con=connection_sqlalchemy)

# %%
zad1.shape[0]
# Out:
# 16

# %% [markdown]
# Zadanie 2

# %%
zad1
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel

# %% [markdown]
# Zadanie 3

# %%
zad3 = pd.read_sql('select title, release_year from film', con=connection_sqlalchemy)

# %%
zad3.sort_values(by='release_year')[-2:]
# wszystkie filmy wyszły w tym samym roku 2006
# Out:
#                  title  release_year
# 328  Forever Candidate          2006
# 999          Zorro Ark          2006

# %% [markdown]
# Zadanie 4

# %%
zad4 = pd.read_sql("select rental_date from rental WHERE rental_date BETWEEN '2005-07-01' AND '2005-08-01'", con=connection_sqlalchemy)

# %%
zad4.shape[0]
# Out:
# 6709

# %% [markdown]
# Zadanie 5

# %%
zad5 = pd.read_sql("select rental_date from rental WHERE rental_date BETWEEN '2010-01-01' AND '2011-02-01'", con=connection_sqlalchemy)

# %%
zad5
# Out:
# Empty DataFrame
# Columns: [rental_date]
# Index: []

# %% [markdown]
# Zadanie 6

# %%
zad6 = pd.read_sql('select amount from payment', con=connection_sqlalchemy)

# %%
zad6.max()
# Out:
# amount    11.99
# dtype: float64

# %% [markdown]
# Zadanie 7

# %%
zad7_customer = pd.read_sql('select * from customer', con=connection_sqlalchemy)
zad7_add = pd.read_sql('select * from address', con=connection_sqlalchemy)
zad7_city = pd.read_sql('select * from city', con=connection_sqlalchemy)
zad7_country = pd.read_sql('select * from country', con=connection_sqlalchemy)

# %%
zad7_pol = zad7_country[zad7_country['country'] == 'Poland']
zad7_nig = zad7_country[zad7_country['country'] == 'Nigeria']
zad7_bang = zad7_country[zad7_country['country'] == 'Bangladesh']
country_ids = [int(a['country_id']) for a in [zad7_pol, zad7_nig, zad7_bang]]

# %%
city_ids = zad7_city['city_id'][(zad7_city['country_id'] == country_ids[0]) | (zad7_city['country_id'] == country_ids[1]) | (zad7_city['country_id'] == country_ids[2])].tolist()

# %%
add_ids = zad7_add[zad7_add.address_id.isin(city_ids)]['address_id'].tolist()

# %%
zad7_customer[zad7_customer.address_id.isin(add_ids)]
# Out:
#      customer_id  store_id   first_name   last_name  \
# 65            65         2         Rose      Howard
# 93            93         1      Phyllis      Foster
# 129          129         1       Carrie      Porter
# 137          137         2       Rhonda     Kennedy
# 139          139         1        Amber       Dixon
# 148          148         1      Eleanor        Hunt
# 213          213         1         Gina  Williamson
# 214          214         1      Kristin    Johnston
# 216          216         1      Natalie       Meyer
# 230          230         2          Joy      George
# 232          232         2    Constance        Reid
# 248          248         1     Caroline      Bowman
# 251          251         2       Vickie      Brewer
# 309          309         1  Christopher       Greco
# 369          369         2         Fred       Wheat
# 376          376         1        Randy     Gaither
# 384          384         2       Ernest       Stepp
# ...

# %% [markdown]
# Zadanie 8

# %%
zad8_cu = pd.read_sql('select * from staff', con=connection_sqlalchemy)
zad8_ad = pd.read_sql('select * from address', con=connection_sqlalchemy)
zad8_ci = pd.read_sql('select * from city', con=connection_sqlalchemy)

# %%
zad8_cu
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
# 1         2    True      Jon  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update  \
# 0 2006-05-16 16:13:11.793280
# 1 2006-05-16 16:13:11.793280
#
#                                              picture
# 0  [b'\x89', b'P', b'N', b'G', b'\r', b'\n', b'Z'...
# 1                                               None

# %%
streets = zad8_ad[zad8_ad.address_id.isin(zad8_cu['address_id'].tolist())]['address'].tolist()

# %%
cities = zad8_ci[zad8_ci.city_id.isin(zad8_ad[zad8_ad.address_id.isin(zad8_cu['address_id'].tolist())]['city_id'].tolist())]['city'].tolist()

# %%
print(streets[0] + ', ' + cities[0])
print(streets[1] + ', ' + cities[1])
# Out:
# 23 Workhaven Lane, Lethbridge
# 1411 Lillydale Drive, Woodridge

# %%
zad7_country
# Out:
#      country_id               country         last_update
# 0             1           Afghanistan 2006-02-15 09:44:00
# 1             2               Algeria 2006-02-15 09:44:00
# 2             3        American Samoa 2006-02-15 09:44:00
# 3             4                Angola 2006-02-15 09:44:00
# 4             5              Anguilla 2006-02-15 09:44:00
# ..          ...                   ...                 ...
# 104         105               Vietnam 2006-02-15 09:44:00
# 105         106  Virgin Islands, U.S. 2006-02-15 09:44:00
# 106         107                 Yemen 2006-02-15 09:44:00
# 107         108            Yugoslavia 2006-02-15 09:44:00
# 108         109                Zambia 2006-02-15 09:44:00
#
# [109 rows x 3 columns]

# %% [markdown]
# Zadanie 9

# %%
zad7_country[zad7_country.country_id.isin(zad8_ci[zad8_ci.city_id.isin(zad8_ad[zad8_ad.address_id.isin(zad8_cu['address_id'].tolist())]['city_id'].tolist())]['country_id'].tolist())]['country'].tolist()
# Out:
# ['Australia', 'Canada']

# %% [markdown]
# Zatem nikt z pracowników nie mieszka w słonecznej Hiszpanii lub Agrentynie.

# %% [markdown]
# Zadanie 10

# %%
zad10_in = pd.read_sql('select * from inventory', con=connection_sqlalchemy)
zad10_re = pd.read_sql('select inventory_id from rental', con=connection_sqlalchemy)
zad10_fc = pd.read_sql('select film_id, category_id from film_category', con=connection_sqlalchemy)
zad10_ca = pd.read_sql('select category_id, name from category', con=connection_sqlalchemy)

# %%
zad10_ca[zad10_ca.category_id.isin(zad10_fc[zad10_fc.film_id.isin(zad10_in[zad10_in.inventory_id.isin(zad10_re['inventory_id'].unique().tolist())]['film_id'].unique())]['category_id'].unique())]['name']
# Out:
# 0          Action
# 1       Animation
# 2        Children
# 3        Classics
# 4          Comedy
# 5     Documentary
# 6           Drama
# 7          Family
# 8         Foreign
# 9           Games
# 10         Horror
# 11          Music
# 12            New
# 13         Sci-Fi
# 14         Sports
# 15         Travel
# Name: name, dtype: object

# %% [markdown]
# Zadanie 11

# %%
co = pd.read_sql('select * from country', con=connection_sqlalchemy)
ci = pd.read_sql('select * from city', con=connection_sqlalchemy)
ad = pd.read_sql('select * from address', con=connection_sqlalchemy)
cu = pd.read_sql('select * from customer', con=connection_sqlalchemy)
re = pd.read_sql('select * from rental', con=connection_sqlalchemy)
inv = pd.read_sql('select * from inventory', con=connection_sqlalchemy)
fi = pd.read_sql('select * from film', con=connection_sqlalchemy)
fc = pd.read_sql('select * from film_category', con=connection_sqlalchemy)
cat = pd.read_sql('select * from category', con=connection_sqlalchemy)

# %%
us_id = co[co['country'] == 'United States']['country_id'].tolist()

# %%
inventories = re[re.customer_id.isin(cu[cu.address_id.isin(ad[ad.city_id.isin(ci[ci.country_id.isin(us_id)]['city_id'])]['address_id'])]['customer_id'])]['inventory_id']

# %%
cat[cat.category_id.isin(fc[fc.film_id.isin(inv[inv.inventory_id.isin(inventories)]['film_id'])]['category_id'])]['name'].unique()
# Out:
# array(['Action', 'Animation', 'Children', 'Classics', 'Comedy',
#        'Documentary', 'Drama', 'Family', 'Foreign', 'Games', 'Horror',
#        'Music', 'New', 'Sci-Fi', 'Sports', 'Travel'], dtype=object)

# %% [markdown]
# Zadanie 12

# %%
names = ['Olympia', 'Julia', 'Ellen']
last_names = ['Pfeiffer', 'Zellweger', 'Presley']
act = pd.read_sql('select * from actor', con=connection_sqlalchemy)
fact = pd.read_sql('select * from film_actor', con=connection_sqlalchemy)
film = pd.read_sql('select * from film', con=connection_sqlalchemy)

# %%
tmp1 = act[act.last_name.isin(last_names)]
tmp2 = tmp1[tmp1.first_name.isin(names)]['actor_id']

# %%
fml = fact[fact.actor_id.isin(tmp2)]['film_id'].tolist()

# %%
film[film.film_id.isin(fml)]
# Out:
#      film_id                 title  \
# 53        49           Badman Dawn
# 76        71       Bilko Anonymous
# 100       95  Breakfast Goldfinger
# 124      120     Caribbean Liberty
# 128      124      Casper Dragonfly
# ..       ...                   ...
# 915      916             Turn Star
# 952      953            Wait Cider
# 981      982          Women Dorado
# 982      983             Won Dares
# 993      994         Wyoming Storm
#
#                                            description  release_year  \
# 53   A Emotional Panorama of a Pioneer And a Compos...          2006
# 76   A Emotional Reflection of a Teacher And a Man ...          2006
# 100  A Beautiful Reflection of a Student And a Stud...          2006
# 124  A Fanciful Tale of a Pioneer And a Technical W...          2006
# 128  A Intrepid Documentary of a Boat And a Crocodi...          2006
# ..                                                 ...           ...
# ...
